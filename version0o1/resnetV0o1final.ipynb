# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Set device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class SarcasmVideoDataset(Dataset):
    def __init__(self, root_dir, label, transform=None):
        self.root_dir = root_dir
        self.label = label
        self.transform = transform
        self.videos = [os.path.join(root_dir, vid) for vid in os.listdir(root_dir) if vid.endswith('.mp4')]

    def __len__(self):
        return len(self.videos)

    def __getitem__(self, idx):
        video_path = self.videos[idx]
        frames = self.extract_frames(video_path)
        if self.transform:
            frames = [self.transform(frame) for frame in frames]
        return torch.stack(frames), self.label

    def extract_frames(self, video_path):
        """Extract frames from video."""
        cap = cv2.VideoCapture(video_path)
        frames = []
        while len(frames) < 10:  # Extract 10 frames for simplicity
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.resize(frame, (224, 224))
            frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        cap.release()
        return frames

# Define transforms for frames
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load datasets
sarcastic_dataset = SarcasmVideoDataset("C:/Users/Rifat/Music/dsv1/sarcastic", label=1, transform=transform)
nonsarcastic_dataset = SarcasmVideoDataset("C:/Users/Rifat/Music/dsv1/nonsarcastic", label=0, transform=transform)

# Combine and split datasets
full_dataset = sarcastic_dataset + nonsarcastic_dataset
train_size = int(0.7 * len(full_dataset))
val_size = int(0.15 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
class VideoClassifier(nn.Module):
    def __init__(self):
        super(VideoClassifier, self).__init__()
        self.feature_extractor = models.resnet18(pretrained=True)
        self.feature_extractor.fc = nn.Identity()  # Remove the final classification layer
        self.lstm = nn.LSTM(512, 128, batch_first=True)
        self.fc = nn.Linear(128, 2)

    def forward(self, x):
        batch_size, frames, c, h, w = x.size()
        x = x.view(batch_size * frames, c, h, w)
        features = self.feature_extractor(x)
        features = features.view(batch_size, frames, -1)
        _, (hn, _) = self.lstm(features)
        out = self.fc(hn[-1])
        return out

model = VideoClassifier().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Out:
# C:\Users\Rifat\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Rifat\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
save_path = "C:/Users/Rifat/Music/Models/ver0o1"

def train_model(model, train_loader, val_loader, num_epochs=5):
    best_acc = 0.0
    for epoch in range(num_epochs):
        model.train()
        train_loss, correct, total = 0.0, 0, 0
        
        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

        train_acc = 100. * correct / total
        val_acc = evaluate_model(model, val_loader)
        print(f"Epoch {epoch+1}, Train Accuracy: {train_acc:.2f}%, Validation Accuracy: {val_acc:.2f}%")

        # Save model if validation accuracy improves
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), f"{save_path}/video_resnet_epoch{epoch+1}_val{val_acc:.2f}.pt")

def evaluate_model(model, val_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
    return 100. * correct / total

train_model(model, train_loader, val_loader)
# Out:
# Epoch [1/5], Batch [1/97], Loss: 0.6942
# Epoch [1/5], Batch [2/97], Loss: 0.7543
# Epoch [1/5], Batch [3/97], Loss: 0.9721
# Epoch [1/5], Batch [4/97], Loss: 0.7537
# Epoch [1/5], Batch [5/97], Loss: 0.7813
# Epoch [1/5], Batch [6/97], Loss: 0.5587
# Epoch [1/5], Batch [7/97], Loss: 0.7063
# Epoch [1/5], Batch [8/97], Loss: 0.7231
# Epoch [1/5], Batch [9/97], Loss: 0.7363
# Epoch [1/5], Batch [10/97], Loss: 0.6373
# Epoch [1/5], Batch [11/97], Loss: 0.7285
# Epoch [1/5], Batch [12/97], Loss: 0.5205
# Epoch [1/5], Batch [13/97], Loss: 0.6149
# Epoch [1/5], Batch [14/97], Loss: 0.6158
# Epoch [1/5], Batch [15/97], Loss: 0.6654
# Epoch [1/5], Batch [16/97], Loss: 0.5538
# Epoch [1/5], Batch [17/97], Loss: 0.7420
# Epoch [1/5], Batch [18/97], Loss: 0.8889
# Epoch [1/5], Batch [19/97], Loss: 0.6935
# Epoch [1/5], Batch [20/97], Loss: 0.6600
# Epoch [1/5], Batch [21/97], Loss: 0.9008
# Epoch [1/5], Batch [22/97], Loss: 0.8512
# Epoch [1/5], Batch [23/97], Loss: 0.6137
# Epoch [1/5], Batch [24/97], Loss: 0.6708
# Epoch [1/5], Batch [25/97], Loss: 0.6844
# Epoch [1/5], Batch [26/97], Loss: 0.7523
# Epoch [1/5], Batch [27/97], Loss: 0.7207
# Epoch [1/5], Batch [28/97], Loss: 0.6923
# Epoch [1/5], Batch [29/97], Loss: 0.6532
# Epoch [1/5], Batch [30/97], Loss: 0.7513
# Epoch [1/5], Batch [31/97], Loss: 0.5460
# Epoch [1/5], Batch [32/97], Loss: 0.6206
# Epoch [1/5], Batch [33/97], Loss: 0.8158
# Epoch [1/5], Batch [34/97], Loss: 0.8018
# Epoch [1/5], Batch [35/97], Loss: 0.6604
# Epoch [1/5], Batch [36/97], Loss: 0.6056
# Epoch [1/5], Batch [37/97], Loss: 0.5862
# Epoch [1/5], Batch [38/97], Loss: 0.6319
# Epoch [1/5], Batch [39/97], Loss: 0.6164
# Epoch [1/5], Batch [40/97], Loss: 0.7077
# Epoch [1/5], Batch [41/97], Loss: 0.7982
# Epoch [1/5], Batch [42/97], Loss: 0.7472
# Epoch [1/5], Batch [43/97], Loss: 0.8569
# Epoch [1/5], Batch [44/97], Loss: 0.6042
# Epoch [1/5], Batch [45/97], Loss: 0.7885
# Epoch [1/5], Batch [46/97], Loss: 0.7402
# Epoch [1/5], Batch [47/97], Loss: 0.6578
# Epoch [1/5], Batch [48/97], Loss: 0.6845
# Epoch [1/5], Batch [49/97], Loss: 0.6881
# Epoch [1/5], Batch [50/97], Loss: 0.6886
# Epoch [1/5], Batch [51/97], Loss: 0.6504
# Epoch [1/5], Batch [52/97], Loss: 0.6861
# Epoch [1/5], Batch [53/97], Loss: 0.6464
# Epoch [1/5], Batch [54/97], Loss: 0.6880
# Epoch [1/5], Batch [55/97], Loss: 0.6758
# Epoch [1/5], Batch [56/97], Loss: 0.6871
# Epoch [1/5], Batch [57/97], Loss: 0.7215
# Epoch [1/5], Batch [58/97], Loss: 0.6529
# Epoch [1/5], Batch [59/97], Loss: 0.6654
# Epoch [1/5], Batch [60/97], Loss: 0.6017
# Epoch [1/5], Batch [61/97], Loss: 0.5840
# Epoch [1/5], Batch [62/97], Loss: 0.5748
# Epoch [1/5], Batch [63/97], Loss: 0.6418
# Epoch [1/5], Batch [64/97], Loss: 0.8245
# Epoch [3/5], Batch [30/97], Loss: 0.7078
# Epoch [3/5], Batch [31/97], Loss: 0.8466
# Epoch [3/5], Batch [32/97], Loss: 0.7005
# Epoch [3/5], Batch [33/97], Loss: 0.5300
# Epoch [3/5], Batch [34/97], Loss: 0.5869
# Epoch [3/5], Batch [35/97], Loss: 0.7412
# Epoch [3/5], Batch [36/97], Loss: 0.6494
# Epoch [3/5], Batch [37/97], Loss: 0.5767
# Epoch [3/5], Batch [38/97], Loss: 0.7149
# Epoch [3/5], Batch [39/97], Loss: 0.7854
# Epoch [3/5], Batch [40/97], Loss: 0.7109
# Epoch [3/5], Batch [41/97], Loss: 0.6697
# Epoch [3/5], Batch [42/97], Loss: 0.6716
# Epoch [3/5], Batch [43/97], Loss: 0.5330
# Epoch [3/5], Batch [44/97], Loss: 0.7430
# Epoch [3/5], Batch [45/97], Loss: 0.6348
# Epoch [3/5], Batch [46/97], Loss: 0.6301
# Epoch [3/5], Batch [47/97], Loss: 0.6850
# Epoch [3/5], Batch [48/97], Loss: 0.6100
# Epoch [3/5], Batch [49/97], Loss: 0.6448
# Epoch [3/5], Batch [50/97], Loss: 0.6785
# Epoch [3/5], Batch [51/97], Loss: 0.5925
# Epoch [3/5], Batch [52/97], Loss: 0.7822
# Epoch [3/5], Batch [53/97], Loss: 0.6818
# Epoch [3/5], Batch [54/97], Loss: 0.5997
# Epoch [3/5], Batch [55/97], Loss: 0.6445
# Epoch [3/5], Batch [56/97], Loss: 0.6754
# Epoch [3/5], Batch [57/97], Loss: 0.5522
# Epoch [3/5], Batch [58/97], Loss: 0.6163
# Epoch [3/5], Batch [59/97], Loss: 0.6160
# Epoch [3/5], Batch [60/97], Loss: 0.7219
# Epoch [3/5], Batch [61/97], Loss: 0.6499
# Epoch [3/5], Batch [62/97], Loss: 0.7259
# Epoch [3/5], Batch [63/97], Loss: 0.6653
# Epoch [3/5], Batch [64/97], Loss: 0.7296
# Epoch [3/5], Batch [65/97], Loss: 0.5330
# Epoch [3/5], Batch [66/97], Loss: 0.5939
# Epoch [3/5], Batch [67/97], Loss: 0.7306
# Epoch [3/5], Batch [68/97], Loss: 0.6559
# Epoch [3/5], Batch [69/97], Loss: 0.5104
# Epoch [3/5], Batch [70/97], Loss: 0.7343
# Epoch [3/5], Batch [71/97], Loss: 0.6744
# Epoch [3/5], Batch [72/97], Loss: 0.6709
# Epoch [3/5], Batch [73/97], Loss: 0.7349
# Epoch [3/5], Batch [74/97], Loss: 0.6616
# Epoch [3/5], Batch [75/97], Loss: 0.5901
# Epoch [3/5], Batch [76/97], Loss: 0.6627
# Epoch [3/5], Batch [77/97], Loss: 0.6606
# Epoch [3/5], Batch [78/97], Loss: 0.6631
# Epoch [3/5], Batch [79/97], Loss: 0.5857
# Epoch [3/5], Batch [80/97], Loss: 0.7394
# Epoch [3/5], Batch [81/97], Loss: 0.7402
# Epoch [3/5], Batch [82/97], Loss: 0.8236
# Epoch [3/5], Batch [83/97], Loss: 0.8161
# Epoch [3/5], Batch [84/97], Loss: 0.5212
# Epoch [3/5], Batch [85/97], Loss: 0.6656
# Epoch [3/5], Batch [86/97], Loss: 0.5929
# Epoch [3/5], Batch [87/97], Loss: 0.6559
# Epoch [3/5], Batch [88/97], Loss: 0.6629
# Epoch [3/5], Batch [89/97], Loss: 0.6012
# Epoch [3/5], Batch [90/97], Loss: 0.5958
# Epoch [3/5], Batch [91/97], Loss: 0.7917
# Epoch [3/5], Batch [92/97], Loss: 0.6014
# Epoch [3/5], Batch [93/97], Loss: 0.7935
# Epoch [3/5], Batch [94/97], Loss: 0.6118
# Epoch [3/5], Batch [95/97], Loss: 0.7792
# Epoch [3/5], Batch [96/97], Loss: 0.7167
# Epoch [3/5], Batch [97/97], Loss: 0.7492
# Epoch 3, Train Accuracy: 60.77%, Validation Accuracy: 62.05%
# Epoch [4/5], Batch [1/97], Loss: 0.7202
# Epoch [4/5], Batch [2/97], Loss: 0.7749
# Epoch [4/5], Batch [3/97], Loss: 0.7090
# Epoch [4/5], Batch [4/97], Loss: 0.6509
# Epoch [4/5], Batch [5/97], Loss: 0.6567
# Epoch [4/5], Batch [6/97], Loss: 0.8085
# Epoch [4/5], Batch [7/97], Loss: 0.6571
# Epoch [4/5], Batch [8/97], Loss: 0.7342
# Epoch [4/5], Batch [9/97], Loss: 0.6651
# Epoch [4/5], Batch [10/97], Loss: 0.6347
# Epoch [4/5], Batch [11/97], Loss: 0.7751
# Epoch [4/5], Batch [12/97], Loss: 0.6602
# Epoch [4/5], Batch [13/97], Loss: 0.6122
# Epoch [4/5], Batch [14/97], Loss: 0.6508
# Epoch [4/5], Batch [15/97], Loss: 0.7708
# Epoch [4/5], Batch [16/97], Loss: 0.6526
# Epoch [4/5], Batch [17/97], Loss: 0.6412
# Epoch [4/5], Batch [18/97], Loss: 0.6710
# Epoch [4/5], Batch [19/97], Loss: 0.6410
# Epoch [4/5], Batch [20/97], Loss: 0.7672
# Epoch [4/5], Batch [21/97], Loss: 0.7228
# Epoch [4/5], Batch [22/97], Loss: 0.7410
# Epoch [4/5], Batch [23/97], Loss: 0.6002
# Epoch [4/5], Batch [24/97], Loss: 0.6106
# Epoch [4/5], Batch [25/97], Loss: 0.6362
# Epoch [4/5], Batch [26/97], Loss: 0.6514
# Epoch [4/5], Batch [27/97], Loss: 0.7064
# Epoch [4/5], Batch [28/97], Loss: 0.6872
# Epoch [4/5], Batch [29/97], Loss: 0.6862
# Epoch [4/5], Batch [30/97], Loss: 0.7352
# Epoch [4/5], Batch [31/97], Loss: 0.6684
# Epoch [4/5], Batch [32/97], Loss: 0.6157
# Epoch [4/5], Batch [33/97], Loss: 0.5505
# Epoch [4/5], Batch [34/97], Loss: 0.7913
# Epoch [4/5], Batch [35/97], Loss: 0.6003
# Epoch [4/5], Batch [36/97], Loss: 0.6674
# Epoch [4/5], Batch [37/97], Loss: 0.7242
# Epoch [4/5], Batch [38/97], Loss: 0.5682
# Epoch [4/5], Batch [39/97], Loss: 0.7322
# Epoch [4/5], Batch [40/97], Loss: 0.5638
# Epoch [4/5], Batch [41/97], Loss: 0.6791
# Epoch [4/5], Batch [42/97], Loss: 0.5405
# Epoch [4/5], Batch [43/97], Loss: 0.7136
# Epoch [4/5], Batch [44/97], Loss: 0.6531
# Epoch [4/5], Batch [45/97], Loss: 0.6741
# Epoch [4/5], Batch [46/97], Loss: 0.6650
# Epoch [4/5], Batch [47/97], Loss: 0.6628
# Epoch [4/5], Batch [48/97], Loss: 0.7423
# Epoch [4/5], Batch [49/97], Loss: 0.7870
# Epoch [4/5], Batch [50/97], Loss: 0.6556
# Epoch [4/5], Batch [51/97], Loss: 0.7186
# Epoch [4/5], Batch [52/97], Loss: 0.5430
# Epoch [4/5], Batch [53/97], Loss: 0.5381
# Epoch [4/5], Batch [54/97], Loss: 0.6006
# Epoch [4/5], Batch [55/97], Loss: 0.5385
# Epoch [4/5], Batch [56/97], Loss: 0.6594
# Epoch [4/5], Batch [57/97], Loss: 0.7289
# Epoch [4/5], Batch [58/97], Loss: 0.5964
# Epoch [4/5], Batch [59/97], Loss: 0.5921
# Epoch [4/5], Batch [60/97], Loss: 0.6600
# Epoch [4/5], Batch [61/97], Loss: 0.6643
# Epoch [4/5], Batch [62/97], Loss: 0.8751
# Epoch [4/5], Batch [63/97], Loss: 0.6584
# Epoch [4/5], Batch [64/97], Loss: 0.7379
# Epoch [4/5], Batch [65/97], Loss: 0.8044
# Epoch [4/5], Batch [66/97], Loss: 0.7965
# Epoch [4/5], Batch [67/97], Loss: 0.7308
# Epoch [4/5], Batch [68/97], Loss: 0.5988
# Epoch [4/5], Batch [69/97], Loss: 0.6623
# Epoch [4/5], Batch [70/97], Loss: 0.5965
# Epoch [4/5], Batch [71/97], Loss: 0.6015
# Epoch [4/5], Batch [72/97], Loss: 0.7893
# Epoch [4/5], Batch [73/97], Loss: 0.4754
# Epoch [4/5], Batch [74/97], Loss: 0.6002
# Epoch [4/5], Batch [75/97], Loss: 0.7873
# Epoch [4/5], Batch [76/97], Loss: 0.7251
# Epoch [4/5], Batch [77/97], Loss: 0.7208
# Epoch [4/5], Batch [78/97], Loss: 0.7901
# Epoch [4/5], Batch [79/97], Loss: 0.6653
# Epoch [4/5], Batch [80/97], Loss: 0.6558
# Epoch [4/5], Batch [81/97], Loss: 0.8502
# Epoch [4/5], Batch [82/97], Loss: 0.4953
# Epoch [4/5], Batch [83/97], Loss: 0.6634
# Epoch [4/5], Batch [84/97], Loss: 0.6606
# Epoch [4/5], Batch [85/97], Loss: 0.6055
# Epoch [4/5], Batch [86/97], Loss: 0.7183
# Epoch [4/5], Batch [87/97], Loss: 0.5470
# Epoch [4/5], Batch [88/97], Loss: 0.7740
# Epoch [4/5], Batch [89/97], Loss: 0.6140
# Epoch [4/5], Batch [90/97], Loss: 0.7114
# Epoch [4/5], Batch [91/97], Loss: 0.6116
# Epoch [4/5], Batch [92/97], Loss: 0.6686
# Epoch [4/5], Batch [93/97], Loss: 0.6619
# Epoch [4/5], Batch [94/97], Loss: 0.7254
# Epoch [4/5], Batch [95/97], Loss: 0.7142
# Epoch [4/5], Batch [96/97], Loss: 0.7154
# Epoch [4/5], Batch [97/97], Loss: 0.5570
# Epoch 4, Train Accuracy: 60.77%, Validation Accuracy: 62.05%
# Epoch [5/5], Batch [1/97], Loss: 0.5484
# Epoch [5/5], Batch [2/97], Loss: 0.7778
# Epoch [5/5], Batch [3/97], Loss: 0.7760
# Epoch [5/5], Batch [4/97], Loss: 0.7213
# Epoch [5/5], Batch [5/97], Loss: 0.6034
# Epoch [5/5], Batch [6/97], Loss: 0.6670
# Epoch [5/5], Batch [7/97], Loss: 0.6066
# Epoch [5/5], Batch [8/97], Loss: 0.6171
# Epoch [5/5], Batch [9/97], Loss: 0.7724
# Epoch [5/5], Batch [10/97], Loss: 0.5659
# Epoch [5/5], Batch [11/97], Loss: 0.6052
# Epoch [5/5], Batch [12/97], Loss: 0.6640
# Epoch [5/5], Batch [13/97], Loss: 0.7106
# Epoch [5/5], Batch [14/97], Loss: 0.6718
# Epoch [5/5], Batch [15/97], Loss: 0.7216
# Epoch [5/5], Batch [16/97], Loss: 0.6021
# Epoch [5/5], Batch [17/97], Loss: 0.4867
# Epoch [5/5], Batch [18/97], Loss: 0.6660
# Epoch [5/5], Batch [19/97], Loss: 0.6592
# Epoch [5/5], Batch [20/97], Loss: 0.6639
# Epoch [5/5], Batch [21/97], Loss: 0.7836
# Epoch [5/5], Batch [22/97], Loss: 0.7904
# Epoch [5/5], Batch [23/97], Loss: 0.5337
# Epoch [5/5], Batch [24/97], Loss: 0.5959
# Epoch [5/5], Batch [25/97], Loss: 0.7283
# Epoch [5/5], Batch [26/97], Loss: 0.7951
# Epoch [5/5], Batch [27/97], Loss: 0.5474
# Epoch [5/5], Batch [28/97], Loss: 0.6527
# Epoch [5/5], Batch [29/97], Loss: 0.6014
# Epoch [5/5], Batch [30/97], Loss: 0.9238
# Epoch [5/5], Batch [31/97], Loss: 0.7285
# Epoch [5/5], Batch [32/97], Loss: 0.7236
# Epoch [5/5], Batch [33/97], Loss: 0.6717
# Epoch [5/5], Batch [34/97], Loss: 0.7771
# Epoch [5/5], Batch [35/97], Loss: 0.5425
# Epoch [5/5], Batch [36/97], Loss: 0.7249
# Epoch [5/5], Batch [37/97], Loss: 0.8290
# Epoch [5/5], Batch [38/97], Loss: 0.6104
# Epoch [5/5], Batch [39/97], Loss: 0.8300
# Epoch [5/5], Batch [40/97], Loss: 0.7128
# Epoch [5/5], Batch [41/97], Loss: 0.7701
# Epoch [5/5], Batch [42/97], Loss: 0.7621
# Epoch [5/5], Batch [43/97], Loss: 0.6196
# Epoch [5/5], Batch [44/97], Loss: 0.6589
# Epoch [5/5], Batch [45/97], Loss: 0.6195
# Epoch [5/5], Batch [46/97], Loss: 0.7147
# Epoch [5/5], Batch [47/97], Loss: 0.6172
# Epoch [5/5], Batch [48/97], Loss: 0.6338
# Epoch [5/5], Batch [49/97], Loss: 0.7487
# Epoch [5/5], Batch [50/97], Loss: 0.6653
# Epoch [5/5], Batch [51/97], Loss: 0.7755
# Epoch [5/5], Batch [52/97], Loss: 0.7082
# Epoch [5/5], Batch [53/97], Loss: 0.6715
# Epoch [5/5], Batch [54/97], Loss: 0.6352
# Epoch [5/5], Batch [55/97], Loss: 0.5641
# Epoch [5/5], Batch [56/97], Loss: 0.5604
# Epoch [5/5], Batch [57/97], Loss: 0.6634
# Epoch [5/5], Batch [58/97], Loss: 0.6675
# Epoch [5/5], Batch [59/97], Loss: 0.7448
# Epoch [5/5], Batch [60/97], Loss: 0.6264
# Epoch [5/5], Batch [61/97], Loss: 0.5839
# Epoch [5/5], Batch [62/97], Loss: 0.6615
# Epoch [5/5], Batch [63/97], Loss: 0.6158
# Epoch [5/5], Batch [64/97], Loss: 0.6157
# Epoch [5/5], Batch [65/97], Loss: 0.6636
# Epoch [5/5], Batch [66/97], Loss: 0.6673
# Epoch [5/5], Batch [67/97], Loss: 0.6060
# Epoch [5/5], Batch [68/97], Loss: 0.5518
# Epoch [5/5], Batch [69/97], Loss: 0.7215
# Epoch [5/5], Batch [70/97], Loss: 0.9061
# Epoch [5/5], Batch [71/97], Loss: 0.7231
# Epoch [5/5], Batch [72/97], Loss: 0.5953
# Epoch [5/5], Batch [73/97], Loss: 0.5973
# Epoch [5/5], Batch [74/97], Loss: 0.5382
# Epoch [5/5], Batch [75/97], Loss: 0.6000
# Epoch [5/5], Batch [76/97], Loss: 0.5948
# Epoch [5/5], Batch [77/97], Loss: 0.6620
# Epoch [5/5], Batch [78/97], Loss: 0.7284
# Epoch [5/5], Batch [79/97], Loss: 0.7360
# Epoch [5/5], Batch [80/97], Loss: 0.6547
# Epoch [5/5], Batch [81/97], Loss: 0.6696
# Epoch [5/5], Batch [82/97], Loss: 0.5152
# Epoch [5/5], Batch [83/97], Loss: 0.7340
# Epoch [5/5], Batch [84/97], Loss: 0.5134
# Epoch [5/5], Batch [85/97], Loss: 0.8124
# Epoch [5/5], Batch [86/97], Loss: 0.6618
# Epoch [5/5], Batch [87/97], Loss: 0.5810
# Epoch [5/5], Batch [88/97], Loss: 0.6702
# Epoch [5/5], Batch [89/97], Loss: 0.8139
# Epoch [5/5], Batch [90/97], Loss: 0.6620
# Epoch [5/5], Batch [91/97], Loss: 0.6601
# Epoch [5/5], Batch [92/97], Loss: 0.7310
# Epoch [5/5], Batch [93/97], Loss: 0.6583
# Epoch [5/5], Batch [94/97], Loss: 0.5889
# Epoch [5/5], Batch [95/97], Loss: 0.7956
# Epoch [5/5], Batch [96/97], Loss: 0.8016
# Epoch [5/5], Batch [97/97], Loss: 0.8400
# Epoch 5, Train Accuracy: 60.77%, Validation Accuracy: 62.05%

# %%
def test_model(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
    print(f"Test Accuracy: {100. * correct / total:.2f}%")

test_model(model, test_loader)
# Out:
# Test Accuracy: 59.28%
